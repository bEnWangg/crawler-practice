# %%
import requests  ##导入requests
from bs4 import BeautifulSoup  ##导入bs4中的BeautifulSoup
import os 
import numpy as np
from PIL import Image
from io import StringIO

# %%
headers = {'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1"}##浏览器请求头（大部分网站没有这个请求头会报错、请务必加上哦）
all_url = 'http://credit-card-generator.2-ee.com/i/out/temp-661.jpg'  ##开始的URL地址
start_html = requests.get(all_url, headers=headers)  ##使用Requests中的get方法来获取all_url（就是：http://www.mzitu.com/all 这个地址）的内容，headers为上面设置的请求头，务必参考Requests官方文档解释
Soup = BeautifulSoup(start_html.text, 'html.parser')

# %% [markdown]
# 跑3001-5000

# %%
for i in range(5000):
    url = str("http://credit-card-generator.2-ee.com/i/out/temp-"+str(i+3001)+".jpg")
    print(url)
    img = requests.get(url)
    with open("credit card" +str(i+3001)+".jpg", 'ab') as f:
        f.write(img.content)
        f.close()
# Out:
# http://credit-card-generator.2-ee.com/i/out/temp-3001.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3002.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3003.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3004.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3005.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3006.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3007.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3008.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3009.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3010.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3011.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3012.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3013.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3014.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3015.jpg
# http://credit-card-generator.2-ee.com/i/out/temp-3016.jpg
# ...
